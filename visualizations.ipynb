# %%
import matplotlib.pyplot as plt
from datautils import tier1results

df = tier1results()

df.hist(column = "improvement", bins = 100)
df.hist(column = "improveZscore", bins = 100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001D93B3EB5C0>]],
#       dtype=object)

# %%
plt.plot(df["divsRank"], df["finalRank"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-160844adfeda> in <module>
# ----> 1 plt.plot(df["divsRank"], df["finalRank"])
#
# AttributeError: module 'matplotlib' has no attribute 'plot'
