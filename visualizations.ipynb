# %%
import matplotlib.pyplot as plt
from datautils import tier1results

df = tier1results()

df.hist(column = "improvement", bins = 100)
df.hist(column = "improveZscore", bins = 100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028A621AD978>]],
#       dtype=object)

# %%
plt.scatter(df["divsRank"], df["finalRank"])
